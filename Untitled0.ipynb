# %%
print("hello, data science bootcamp")
price=1000
discount=0.2
tax=0.12
final_price=price-(price*discount)
fiprice=(final_price*tax)+final_price
print("final price after discount with tax:",fiprice)
print("final price without tax:",final_price)
# Out:
# hello, data science bootcamp
# final price after discount with tax: 896.0
# final price without tax: 800.0

# %%
age=30
salary=55000.0
loan_amount=200000
already_loan=2
credit_score=720
is_citizen=True
#(+,-,\,*)
emi=loan_amount/24
totalsalary_y=salary*12
remain_salary=totalsalary_y -(emi*12)
print(emi)
print(totalsalary_y)
print(remain_salary)
#compare
print("is credit score good?",credit_score>=700)
print("is emi is less than 50% of salary",emi<(salary*0.5))
print("is age less than 60",age<60)
# Out:
# 8333.333333333334
# 660000.0
# 560000.0
# is credit score good? True
# is emi is less than 50% of salary True
# is age less than 60 True

# %%
customer_name= "bhavesh shukla25"
age=25
salary=19999.9
is_fraud=False
print(customer_name)
print(type(customer_name))
print(type(age))
print(type(salary))
print(type(is_fraud))
# Out:
# bhavesh shukla25
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
item1=1200
item2=800
item3=600
discount=0.1
tax=0.18

total_item=item1+item2+item3

final_bill=total_item-(total_item*discount)
total=(final_bill*tax)+final_bill
print("total bill",total_item)
print("final bill with discount",final_bill)
print("bill with tax",total)
# Out:
# total bill 2600
# final bill with discount 2340.0
# bill with tax 2761.2

# %%
marks=int(input("enter your scores:"))
if marks>=95:
  print("grade:O outstanding")
elif marks>=85:
  print("grade:A distinction")
elif marks>=75:
  print("grade:B good")
elif marks>=65:
  print("grade:C average")
else:
  print("grade:D need improvment")
# Out:
# enter your scores:60
# grade:D need improvment

# %%
costumers=["harsh","rahul","sumit","bobby","kartik","55",10.50]

for name in costumers:
  print("sending email to", name)

print("all emails sent")
#
# Out:
# sending email to harsh
# sending email to rahul
# sending email to sumit
# sending email to bobby
# sending email to kartik
# sending email to 55
# sending email to 10.5
# all emails sent

# %%
for i in range(1,6):
  print("rollno.of group:",i)
# Out:
# rollno.of group: 1
# rollno.of group: 2
# rollno.of group: 3
# rollno.of group: 4
# rollno.of group: 5

# %%
students={"sumit":92,"harsh":85,"himmat":65,"raj":50}

for name,marks in students.items():
  if marks>=90:
    grade="A"
  elif marks>=80:
    grade="B"
  else:
    grade="C"

  print(f"student:{name},marks:{marks},Grade:{grade}")
# Out:
# student:sumit,marks:92,Grade:A
# student:harsh,marks:85,Grade:B
# student:himmat,marks:65,Grade:C
# student:raj,marks:50,Grade:C

# %%
def blame(name):
  print("hello", name,"are u mad!")

blame("sumit")
blame("himmat")
blame("aryan")
# Out:
# hello sumit are u mad!
# hello himmat are u mad!
# hello aryan are u mad!

# %%
def money(x,y):
  total=x+y
  return total

money(1000,400)
print(money(500,500))
money(500,1000)
money("abc","xyz")
# Out:
# 1000
# 'abcxyz'

# %%
def eligibility(age):
  print(age)
  if age>=18:
    print("eligible")
  else:
    print("not eligible")

eligibility(21)
eligibility(15)
# Out:
# 21
# eligible
# 15
# not eligible

# %%
print(date)
# Out:
# 2026-02-22

# %%
def issue_books(student_name, books):
  print(f"/n {student_name} borrowed:")
  for book in books:
    print("-", book)

def calculate_fine(days_late):
  fine_per_day=5
  return days_late*fine_per_day

def student_report(student_name,books,days_late):
  issue_books(student_name,books)
  fine=calculate_fine(days_late)
  print(f"fine to be paid: ${fine}\n")

student_report("rahul", ["python basics", "data science 101"], 3)
student_report("priya", ["machine learning"], 0)
# Out:
# /n rahul borrowed:
# - python basics
# - data science 101
# fine to be paid: $15
#
# /n priya borrowed:
# - machine learning
# fine to be paid: $0
